# %% [markdown]
# # 제약조건->sql문이 아닌 테이블 자체에 제약을 거는것
# # 제약조건이 없으면 중복된 행, NULL이 들어간 행들등도 그냥 가져옴
# ![image.png](attachment:24fc3bd1-d219-4b56-8eb5-58f681b298fa.png)

# %% [markdown]
# ![image.png](attachment:7368b47d-c7a5-4e92-a853-8f3edfdd3220.png)

# %% [markdown]
# # 지침
# ![image.png](attachment:921aa52f-5a17-47cf-abd8-4c50c2359d92.png)

# %% [markdown]
# # 구문
# ![image.png](attachment:1f216ed8-cdd8-4601-840c-4b70d8cb04e6.png)

# %% [markdown]
# # 예시)
# ![image.png](attachment:4ab24f06-e558-4d0d-9268-88767bb7bd90.png)

# %% [markdown]
# # 만들어진 테이블에 제약조건 추가
# ![image.png](attachment:30071a61-a158-4fdd-a219-9e8fdd2c3c4d.png)
# 이때 이름을 지정해주지 않아 프로그램이 자동으로 이름 설정

# %% [markdown]
# # 제약조건 지우는 법
# ![image.png](attachment:c95c754d-0c99-48c5-a997-c52248aecda8.png)

# %% [markdown]
# # 테이블 지우기
# ![image.png](attachment:4687e489-02a9-4db2-b065-391ed681a151.png)
# # PURGE는 영구삭제(bin으로 가지도 않음)

# %% [markdown]
# # 테이블 처음 만들면서 제약조건 설정
# ![image.png](attachment:4c1fa99d-6d11-49c2-b32d-235ed08074a5.png)

# %% [markdown]
# # 설정된 제약조건 보는법
# ![image.png](attachment:c68ced4d-a744-4cb5-b010-4820a4367a94.png)
# # or
# ![image.png](attachment:d428a6bb-de75-4c23-90e9-888b13c8dc10.png)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # 제약조건 종류
# # 1. NOT NULL
# ![image.png](attachment:0c8819e8-f85b-4bfe-b090-1c579e096e47.png)
# # NOT NULL제약조건걸린 컬럼에 NULL집어넣으면 error
# ![image.png](attachment:b4b42dee-d221-4529-acd4-28ba61fa1d5e.png)

# %% [markdown]
# # 2. UNIQUE 제약조건
# # 중복을 허용하지 않음-이미 있으면 더이상 못들어오고 error
# ![image.png](attachment:9e4d1687-a0ae-45c3-a2fa-5e2e00342fb4.png)
# # 하지만 NULL은 얼마든지 들어갈 수 있음
# ![image.png](attachment:51c2765d-c6f2-477d-aa35-cb0b5625e0c0.png)
# ![image.png](attachment:bc67bb33-5b1b-4d7d-ae13-86f867240f43.png)

# %% [markdown]
# # 3. PRIMARY KEY 제약조건
# # NULL허용X, 중복도 허용X
# ![image.png](attachment:c6565aef-4808-4e12-bad4-6c2c276aa6f2.png)
# # 예시)
# ![image.png](attachment:54368636-625d-4fac-9ce9-48d361bfefd1.png)
# ![image.png](attachment:b9ab25d9-5a5c-46fa-8c92-bc394816bbe8.png)

# %% [markdown]
# # 4. FOREIGN KEY 제약조건
# # 다른 테이블 참조하면서 그 안에 존재하는 값만 쓸수있음(R의 factor)
# # 레퍼런스 (테이블(컬럼)) 필요
# ![image.png](attachment:4b94178a-aaff-42e8-b726-e01566dd3434.png)
# ![image.png](attachment:6b00b4f4-95ae-4524-9537-4d565f333ad1.png)
# # 예시
# ![image.png](attachment:b3ec2a6a-1d9b-4c20-a7b2-c1a1436d555f.png)
# # 특징-삭제안됨
# ![image.png](attachment:d99023da-bbc5-4a60-b2a5-17d726cac3da.png)

# %% [markdown]
# # 삭제 가능해질려면?
# # ON DELETE SET NULL  -> foreign key제약걸린애들 삭제하면 NULL로 채울것이다
# ![image.png](attachment:102ecf2f-35e2-4fad-b234-c5ef412b48f4.png)
# # 예시
# ![image.png](attachment:b113c577-465b-4fa7-9352-fafa8561a944.png)
# # DEPTNO칸만 지움
# ![image.png](attachment:bb5e116c-059c-453b-938a-e678bef14eb7.png)

# %% [markdown]
# # or
# # ON DELETE cascade-> 그 행 전부 삭제
# ![image.png](attachment:9efb31a4-aa94-4a3b-9fc7-6169a734f845.png)

# %% [markdown]
# # 5. CHECK제약조건
# # 조건을 충족해야함
# ![image.png](attachment:40a12767-fb88-4ad1-8b86-4f559af81bda.png)

# %% [markdown]
# # 제약조건문 예제
# ![image.png](attachment:953fa2b4-84ef-4a1b-b584-b05eaef8c5fd.png)
