# %% [markdown]
# # 1. 데이터 변경: update문
# ![image.png](attachment:cadfed86-a3fe-40d5-8ed4-952261e499b0.png)

# %% [markdown]
# # where 유무
# ![image.png](attachment:d71ef4c4-8fbb-4716-8ef8-4a7306885459.png)

# %% [markdown]
# # 여러열 갱신할때는 subquery이용
# # set (a,b)=(select c,d from e where f=g) where f=h
# ![image.png](attachment:e672de83-288c-42e3-b7a0-67d4961a57c0.png)

# %% [markdown]
# ![image.png](attachment:58f4e4ee-08b6-4851-a988-e88509f58523.png)

# %% [markdown]
# # 2. 행 제거: delete문
# ![image.png](attachment:361c9f63-bad5-4590-b361-b797066f61a3.png)

# %% [markdown]
# # where 유무
# ![image.png](attachment:2c5e9275-9138-4076-855a-3132df20fe82.png)

# %% [markdown]
# # subquery로
# ![image.png](attachment:8b5475c4-9953-48df-a729-cef8769a58f2.png)

# %% [markdown]
# ---
# ---
# ---
# # TRUNCATE TABLE
# # DDL(data definition language)->DML과 다름
# # rollback불과하므로 항상 신중히
# ![image.png](attachment:c9a8d8ac-2eee-4c94-9377-ef90faed39ef.png)
