# %% [markdown]
# # 데이터베이스 트랜잭션
# # 트랜잭션=DB의 상태를 변경시키는 작업의 단위(한꺼번에 수행되어야 할 연산을 모아놓은것)
# ![image.png](attachment:ae99a263-be07-44c9-a504-d1d10ebb237c.png)

# %% [markdown]
# # TCL(transaction control language)
# # commit
# # rollback
# # savepoint

# %% [markdown]
# # 변경 적용의 시작과 끝
# ![image.png](attachment:1275e826-ceb4-429a-986f-df70f3151249.png)

# %% [markdown]
# # 트랜잭션 방식의 이점
# ![image.png](attachment:950c343a-1f45-479e-8569-8f4230900a2e.png)

# %% [markdown]
# # 설정 시 원하는 지점으로 롤백 가능
# ![image.png](attachment:cc70f0b1-29ba-4488-bd37-22b8c0c4ff85.png)

# %% [markdown]
# # savepoint문
# ![image.png](attachment:7d32e0fc-e767-4222-a59a-d7fe52438642.png)

# %% [markdown]
# # 예제)
# ![image.png](attachment:213aa5a2-69fd-4333-841c-4209b9fef7f1.png)
# ![image.png](attachment:76a09d8f-ffbc-47d6-8d6c-ff0dcf63ecbd.png)
# # B로 돌아감
# ![image.png](attachment:8c2f8735-fd6d-4910-8dbd-0511d6f96fd4.png)
# # 그런데도 더 되돌리고 싶으면 더 전으로(savepoint생략가능)

# %% [markdown]
# # 자동 commit되는 경우
# ![image.png](attachment:e5e62146-b7a2-4655-be16-608f038f393e.png)
