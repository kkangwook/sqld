# %% [markdown]
# # DCL(Data Control Language)
# ### grant-부여
# ### revoke-회수

# %% [markdown]
# # 1.GRANT
# ![image.png](attachment:19ee7d3b-aed7-43a3-aa95-83893a00a58f.png)
# ![image.png](attachment:28dcfd73-dad4-4ed1-b388-81d69e03fc12.png)

# %% [markdown]
# # 2. REVOKE
# ![image.png](attachment:ad12437d-cf78-46b6-9c2b-7561fa4a7ed0.png)

# %% [markdown]
# # 3. ROLE
# ## 반복적으로 grant, revoke해야할 경우 role설정으로 간편하게
# ## 롤 생성 -> 롤에 권한부여 -> 그 롤을 사용자에 배정 -> 회수
# # 롤 생성
# ![image.png](attachment:0635307e-b3c9-49c3-8f52-0836c9acb9c5.png)
# # 롤에 권한부여
# ![image.png](attachment:7d155e40-eed3-4107-a5dc-2c4472f677f0.png)
# # 롤에 사용자 배정
# ![image.png](attachment:0a782622-a0e8-4cbd-b15c-af7b7307c972.png)
# # 사용자로부터 롤 회수
# ![image.png](attachment:d230c5fd-c09b-4209-a8c2-944a0c614ee5.png)
# # 롤에 부여된 권한 회수
# ![image.png](attachment:0ebf322a-75d4-451f-a787-d1386dbaa824.png)
# # 롤 삭제
# ![image.png](attachment:38839cda-cc6d-4962-9c41-68a20d0532ce.png)
