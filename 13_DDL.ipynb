# %% [markdown]
# # DDL(data definition language)
# # create
# # alter
# # drop
# # truncate
# # rename(기존 테이블 이름 변경)

# %% [markdown]
# # 1. CREATE TABLE

# %% [markdown]
# # CREATE TABLE과 AS subquery 결합하여 테이블 생성
# ![image.png](attachment:8e3a090b-a552-4cef-831e-fb97e60d573b.png)

# %% [markdown]
# # 실제구문)
# # CTAS(create table as select)
# ![image.png](attachment:77e8f434-0026-4145-9b5a-7bb48c19d4e6.png)
# # 이때 salary*12 만 하면 에러남-> '*'는 컬럼이름이 될 수 없으므로
# # -> salary*12 ANNSAL 로 하여 이름을 ANNSAL로

# %% [markdown]
# # 2. alter table
# ![image.png](attachment:d3b35a15-9e35-40cb-a4b5-fd1c5085bc14.png)

# %% [markdown]
# # 2-1. ADD(열추가)
# ![image.png](attachment:8e307425-9731-48e0-8e48-4ecc4622cc84.png)
# # 맨 뒤에 defalut ' '하면 NULL 대신 그 값들도 채워짐
# # 예시)
# ![image.png](attachment:c05768f9-d95d-4938-93e0-5b5e7280e0fd.png)

# %% [markdown]
# # 2-2. MODIFY(수정)
# ![image.png](attachment:4f3e8049-001a-4052-80e0-a164fe42be0f.png)
# # 예시)
# ![image.png](attachment:15971195-0bfa-42d4-b768-d7c8020b3f84.png)
# # 원래있던 데이터에 따라 수정 안될수도있음(이름을 numer(4)로 수정하는 경우가 에러남)
# # 기본값 설정(default)
# ![image.png](attachment:d80d70fe-3e56-42a3-80f2-8f89c4455514.png)

# %% [markdown]
# # 2-3. DROP(열 삭제)
# ![image.png](attachment:2828c108-3486-4624-8938-e657d6e3c6ed.png)
# # 단점은 그 컬럼을 지우고 그 사이를 이어주느라 시간이 오래걸릴수있음
# # -> 그래서 SET UNUSED 옵션이 있음
# ![image.png](attachment:ceccc01f-77fc-4460-9089-8ffda779b33f.png)
# # 예시)
# ![image.png](attachment:e8be7e02-a0c8-44f2-82d2-dfca9540fdfb.png)
# # unnused col뭔지 보여주는 구문
# ![image.png](attachment:23e2f2ec-c0ec-4fb4-ba1d-57380eaf3dd3.png)
# # unnused col 지우기
# ![image.png](attachment:caef7634-2f15-4bce-a1f3-70d188370e99.png)
# # 한번 unnused되면 다시 못꺼내오니 주의

# %% [markdown]
# # 2.4 READ ONLY(읽기전용)
# # 테이블을 읽기전용으로 만들어 그 테이블은 관리하는동안 변경불가
# ![image.png](attachment:cdbaca74-14dc-440a-9d8f-a87ebc79232d.png)

# %% [markdown]
# # 2.5 DROP TABLE(테이블을 삭제)
# ![image.png](attachment:a89a3d39-6274-41ea-83f7-44f1f7ee0b27.png)
# # 예시)
# ![image.png](attachment:01c90db2-864c-49c0-9082-0aebaf997209.png)
# # 완전 삭제-> PURGE명령->다시 못꺼내옴
# ![image.png](attachment:618c28e5-ceba-444a-9c88-47fee3dc2902.png)

# %% [markdown]
# # 2-6. rename
# ![image.png](attachment:c2166770-f4d7-4798-800c-b216d148adfe.png)
# ![image.png](attachment:fe6015d7-9e8c-4ab8-8a53-53f587bea4df.png)
