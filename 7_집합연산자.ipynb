# %% [markdown]
# # 집합연산자
# ![image.png](attachment:f0696c0d-bc1b-492d-b69d-9e917b8c53b8.png)
# # 이 중 union all만 중복해서 표시

# %% [markdown]
# # 규칙
# ![image.png](attachment:53e527b1-1e51-404c-b39b-67fa7e956e4f.png)
# ![image.png](attachment:c620ca56-ef8f-423c-bb40-f7b07d00a0dd.png)

# %% [markdown]
# # 1. union연산자
# ![image.png](attachment:48f866fb-c1c5-419c-8775-5e1095c07149.png)

# %% [markdown]
# # 예시
# ![image.png](attachment:6c1ac5ae-9d00-4102-b386-a6fd5e966455.png)

# %% [markdown]
# # 2. union all-> 중복도 표시
# ![image.png](attachment:8daec499-c7b4-4c50-8562-45b80cbf4cb2.png)

# %% [markdown]
# # 3. intersect
# ![image.png](attachment:b5147a34-a7c8-4ffd-b870-ab41e15079ec.png)

# %% [markdown]
# # 예시)
# ![image.png](attachment:eedf2c60-2b36-4333-896c-1db03c8891cf.png)

# %% [markdown]
# # 4.minus
# ![image.png](attachment:7533cf06-253d-419a-a41e-18605f21fded.png)

# %% [markdown]
# # 예시)
# ![image.png](attachment:eb430c00-a941-4c6c-b396-2e6d40eb1e8f.png)
#
# ---
# ---
# ![image.png](attachment:4bad6727-e340-432c-bd75-3f2baf3db7d5.png)

# %% [markdown]
# # 예시2)
# ![image.png](attachment:22c559da-1d3d-436b-b53b-2f40165a3316.png)

# %% [markdown]
# ---
# ---
# ---
# # 만약 비교하는 테이블의 컬럼수가 다름면?->컬럼수 같아지게 by TO_CHAR(NULL)
# # 예시1)
# ![image.png](attachment:b87c7525-b0cb-4cef-a555-24c9292bcb9b.png)

# %% [markdown]
# # 예시2)
# ![image.png](attachment:ff4b6bf7-74c4-4dfa-83c7-c107ca9e8247.png)

# %% [markdown]
# ---
# ---
# ---
# # order by절
# ![image.png](attachment:1a5105d0-26ce-4707-9259-1a391f5bfd55.png)

# %% [markdown]
# # 맨끝에 하나만
# ![image.png](attachment:f3acdf29-d51c-4c5b-9d9e-9bd26f0f1fd0.png)
# ![image.png](attachment:da231280-170b-4a4a-912a-b0f5dfe7a2f2.png)

# %% [markdown]
# # 첫번째 쿼리의 열만 인식
# ![image.png](attachment:3975bdf3-e95c-43e8-a3ea-891b41d06be3.png)
# ![image.png](attachment:f71b5ba5-b618-41e4-9c9e-6a8c8d3d4990.png)
