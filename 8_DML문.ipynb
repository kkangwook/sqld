# %% [markdown]
# # DML = data manipulation language
# insert, update, delete
# ![image.png](attachment:476f51b6-325a-4b42-a7b7-37efaa12a6de.png)

# %% [markdown]
# # 1. insert
# ![image.png](attachment:d591fdfa-853c-448b-8515-830f6ea7e9b6.png)

# %% [markdown]
# # 예시)
# ![image.png](attachment:8e1b6e13-4900-4e0a-9348-c4f87d566489.png)

# %% [markdown]
# # 적용)
# ![image.png](attachment:124ed785-9d4b-4fea-8e38-f2719cee1b1b.png)

# %% [markdown]
# # NULL이 존재할시
# ![image.png](attachment:f681cce1-ecdd-450c-9fbd-fa9a87ff9fe0.png)

# %% [markdown]
# # 특수값 삽입(함수 등)
# ![image.png](attachment:420380a2-10c4-4609-b502-f4ad3492fd4a.png)
# ![image.png](attachment:6a4d600a-d5b9-433c-82b9-4077db933f39.png)

# %% [markdown]
# ---
# ---
# # 저장 -> COMMIT
# ![image.png](attachment:386f8018-7a37-4e00-a716-38bd1e2ee9f7.png)

# %% [markdown]
# # 원상태로 ->ROLLBACK
# # 직전에 commit한 구간으로 돌려줌
# ![image.png](attachment:107277b2-f2af-40fa-9e44-0a00dcfbe526.png)

# %% [markdown]
# # insert를뜨는 창으로 각각 저장
# # 컬럼이름앞에 &사용 (python의 input함수와 비슷)
# ![image.png](attachment:a30f725e-fa98-445a-87df-37ef7c3477fb.png)

# %% [markdown]
# # 한번에 여러행 삽입 by subquery
# ![image.png](attachment:503bd9bc-b7cb-4e45-b758-2c36c5fd87d4.png)
